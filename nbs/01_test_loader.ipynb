# %%
from pathlib import Path
import pandas as pd
import sys

ROOT_DIR = Path().cwd().parent


if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))

from src.data import load_daily_data
from src.models import ChartsDailyData

# %%
dict_filename = "../data/0008_80_pct_hl2_movers_scan_20030919_20250402.feather"
data_filename = dict_filename.replace(".feather", "_data.feather")

chart_data = ChartsDailyData(dict_filename, data_filename)
print("Charts loaded:", len(chart_data.charts))
# Out:
# Charts loaded: 13369

# %%
df = chart_data.load_chart(5)
print(df.dtypes)
df.drop(columns=["ticker"])
# Out:
# ticker          category
# date      datetime64[ns]
# open             float32
# high             float32
# low              float32
# close            float32
# volume             int64
# dtype: object
#           date  open    high   low  close  volume
# 0   2021-12-06  1.27  1.3942  1.25   1.39   27550
# 1   2021-12-06  1.27  1.3942  1.25   1.39   27550
# 2   2021-12-07  1.38  1.5899  1.27   1.53   32129
# 3   2021-12-07  1.38  1.5899  1.27   1.53   32129
# 4   2021-12-07  1.38  1.5899  1.27   1.53   32129
# ..         ...   ...     ...   ...    ...     ...
# 120 2022-02-02  1.66  1.7100  1.50   1.63  400447
# 121 2022-02-02  1.66  1.7100  1.50   1.63  400447
# 122 2022-02-03  1.60  1.6400  1.54   1.54   32379
# 123 2022-02-03  1.60  1.6400  1.54   1.54   32379
# 124 2022-02-03  1.60  1.6400  1.54   1.54   32379
#
# [125 rows x 6 columns]

# %%
import numpy as np
n = 100
dates = pd.date_range("2024-06-01", periods=n)
data = {
    "date": dates,
    "open": np.random.uniform(100, 200, n),
    "high": np.random.uniform(200, 300, n),
    "low": np.random.uniform(50, 100, n),
    "close": np.random.uniform(100, 200, n),
    "volume": np.random.randint(1000, 10000, n),
}
df_random = pd.DataFrame(data)
print(df_random.dtypes)
df_random
# Out:
# date      datetime64[ns]
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int32
# dtype: object
#          date        open        high        low       close  volume
# 0  2024-06-01  114.630235  210.006699  58.713384  133.223615    9413
# 1  2024-06-02  163.587454  253.716228  73.084583  169.771755    3163
# 2  2024-06-03  117.371837  263.961433  98.054564  194.127404    8060
# 3  2024-06-04  172.443807  289.463861  77.234867  183.535253    8258
# 4  2024-06-05  103.726722  223.998288  75.015751  178.244747    7817
# ..        ...         ...         ...        ...         ...     ...
# 95 2024-09-04  118.860294  201.285923  68.039336  103.471260    9196
# 96 2024-09-05  189.231482  235.545519  52.724886  138.796193    9002
# 97 2024-09-06  172.637833  271.905020  73.019968  149.535626    1617
# 98 2024-09-07  132.493213  273.068416  98.538282  147.383800    9478
# 99 2024-09-08  107.455941  294.460273  78.161285  183.155596    2898
#
# [100 rows x 6 columns]

# %%
# Out:
#     ticker       date    open    high     low   close    volume
# 0     AACG 2021-12-06  1.2700  1.3942  1.2500  1.3900     27550
# 2     AACG 2021-12-07  1.3800  1.5899  1.2700  1.5300     32129
# 113   AACG 2022-01-31  1.6600  1.6600  1.4800  1.5600     27410
# 116   AACG 2022-02-01  1.5300  1.6500  1.5200  1.6100     55999
# 119   AACG 2022-02-02  1.6600  1.7100  1.5000  1.6300    400447
# 122   AACG 2022-02-03  1.6000  1.6400  1.5400  1.5400     32379

# %%
from lightweight_charts import Chart
chart = Chart()
# chart.set(df.drop(columns=["ticker"]))
chart.set(df)
chart.watermark("Random Data Example")
chart.show(block=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 6
#       4 chart.set(df)
#       5 chart.watermark("Random Data Example")
# ----> 6 chart.show(block=True)
#
# File c:\Users\Lollo\anaconda3\envs\base312\Lib\site-packages\lightweight_charts\chart.py:202, in Chart.show(self, block)
#     200     Chart.WV.show(self._i)
#     201 if block:
# --> 202     asyncio.run(self.show_async())
#
# File c:\Users\Lollo\anaconda3\envs\base312\Lib\asyncio\runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     194     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
for col in df.columns:
    if df[col].dtype == np.float32:
        df[col] = df[col].astype(np.float64)
        
df.dtypes
# Out:
# ticker          category
# date      datetime64[ns]
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# dtype: object

# %%
df = load_daily_data(ticker, date, df_data)
print("Loaded data shape:", df.shape)
print("Data sample:")
df
# Out:
# Loaded data shape: (81, 9)
# Data sample:
#    ticker       date       open       high        low      close    volume  \
# 0      AA 2016-09-12   9.520000   9.800000   9.430000   9.780000  21681919
# 1      AA 2016-09-12   9.520000   9.800000   9.430000   9.780000  21681919
# 2      AA 2016-09-13   9.630000   9.645000   9.450000   9.520000  18507673
# 3      AA 2016-09-13   9.630000   9.645000   9.450000   9.520000  18507673
# 4      AA 2016-09-14   9.690000   9.690000   9.360000   9.390000  15719147
# ..    ...        ...        ...        ...        ...        ...       ...
# 76     AA 2016-11-04  23.820000  25.500000  23.559999  25.200001   6878773
# 77     AA 2016-11-04  23.820000  25.500000  23.559999  25.200001   6878773
# 78     AA 2016-11-07  25.540001  26.410000  24.889999  25.080000   8377625
# 79     AA 2016-11-08  24.299999  26.590000  24.299999  26.400000   6471469
# 80     AA 2016-11-09  26.830000  29.139999  26.000000  28.719999  10676056
#
#     adjusted type
# 0      False   CS
# 1      False   CS
# 2      False   CS
# 3      False   CS
# 4      False   CS
# ..       ...  ...
# 76     False   CS
# 77     False   CS
# 78     False   CS
# 79     False   CS
# 80     False   CS
#
# [81 rows x 9 columns]
